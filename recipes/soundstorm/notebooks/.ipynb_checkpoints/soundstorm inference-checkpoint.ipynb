# %%
# %cd /mlx_devbox/users/janne.spijkervet/repo/333/samantha/
# %load_ext autoreload
# %autoreload 2
# Out:
# /mlx_devbox/users/janne.spijkervet/repo/333/samantha

# %%
import os
from samantha.utils.hdfs_helper import hdfs_ls, get

# arnold_task_id = 558104
# hdfs_ckpt_dir = f"hdfs://harunava/home/byte_arnold_va/data/lab/audio/soundstorm/tasks/{arnold_task_id}/trials"
# checkpoints = list(
#     filter(lambda f: ".ckpt" in f and "step=" in f, hdfs_ls(f"-R {hdfs_ckpt_dir}"))
# )
# checkpoints.reverse()

# get(checkpoints[0], "model.ckpt")

get("hdfs://harunava/home/byte_arnold_va/data/lab/audio/soundstorm/tasks/558104/trials/2808839/output/soundstorm/baseline/checkpoints/epoch=0-step=21500.ckpt", "558104.ckpt")
# Out:
# True

# %%
from recipes.soundstorm.lightning.soundstorm import SoundStorm

device = "cuda"
soundstorm = SoundStorm.load_from_checkpoint("558104.ckpt").to(device)

# %%
import torch
import pandas as pd

semantic_tokens = torch.load("/mnt/bn/audio-diffusion/assets/semantic_decoder_gen_samples_100x250.pt")
semantic_tokens = semantic_tokens[:, None].to(device)


df = pd.read_csv("/mnt/bn/audio-diffusion/data/google_prompts/text_prompt_collection_20230523.csv")
text_prompts = df["text"].tolist()[:len(semantic_tokens)]

# %%
import re
import unicodedata

def slugify(value, allow_unicode=False):
    """
    Taken from https://github.com/django/django/blob/master/django/utils/text.py
    Convert to ASCII if 'allow_unicode' is False. Convert spaces or repeated
    dashes to single dashes. Remove characters that aren't alphanumerics,
    underscores, or hyphens. Convert to lowercase. Also strip leading and
    trailing whitespace, dashes, and underscores.
    """
    value = str(value)
    if allow_unicode:
        value = unicodedata.normalize("NFKC", value)
    else:
        value = (
            unicodedata.normalize("NFKD", value)
            .encode("ascii", "ignore")
            .decode("ascii")
        )
    value = re.sub(r"[^\w\s-]", "", value.lower())
    return re.sub(r"[-\s]+", "-", value).strip("-_")

# %%
import torchaudio
import os
from recipes.soundstorm.inference.semantic2audio import generate

# iterations = [32,32,32,32,8,8,8,8,8,8,8,8]
# score_strategies = ["random", "random", "random", "random", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit"]

iterations = [32,32,32,32,1,1,1,1,1,1,1,1]
score_strategies = ["random", "random", "random", "random", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit", "maskgit"]

out_dir = "generated_2808839"
os.makedirs(out_dir, exist_ok=True)
            
for st, text in zip(semantic_tokens, text_prompts):
    audio = generate(soundstorm, st, max_seq_len=500, iterations=iterations, score_strategies=score_strategies)    
    torchaudio.save(os.path.join(out_dir, f"{slugify(text)}.wav"), audio[0].cpu(), 24000)
# Out:
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:13<00:00,  1.16s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:13<00:00,  1.16s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:13<00:00,  1.16s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:13<00:00,  1.16s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:13<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:13<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:13<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.17s/it]
# Iteratively decoding audio tokens...: 100%|█████| 12/12 [00:14<00:00,  1.18s/it]
# Iteratively decoding audio tokens...:  25%|█▌    | 3/12 [00:09<00:27,  3.11s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 12
#       9 os.makedirs(out_dir, exist_ok=True)
#      11 for st, text in zip(semantic_tokens, text_prompts):
# ---> 12     audio = generate(soundstorm, st, max_seq_len=500, iterations=iterations, score_strategies=score_strategies)
#      13     torchaudio.save(os.path.join(out_dir, f"{slugify(text)}.wav"), audio[0].cpu(), 24000)
#
# File /usr/local/lib/python3.9/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /mlx_devbox/users/janne.spijkervet/repo/333/samantha/recipes/soundstorm/inference/semantic2audio.py:24, in generate(soundstorm, semantic_tokens, max_seq_len, iterations, score_strategies, sampled_t, temperature)
#      14 @torch.no_grad()
#      15 def generate(
#      16     soundstorm: SoundStorm,
#    (...)
#      22     temperature: float = 1.0,
#      23 ):
# ---> 24     pred_tokens, _ = soundstorm.iterative_decoding(
#      25         semantic_tokens,
#      26         max_seq_len=max_seq_len,
#      27         iterations=iterations,
#      28         score_strategies=score_strategies,
#      29         sampled_t=sampled_t,
#      30         temperature=temperature,
#      31     )
#      32     return soundstorm.audio_model.decode(pred_tokens)
#
# File /usr/local/lib/python3.9/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /mlx_devbox/users/janne.spijkervet/repo/333/samantha/recipes/soundstorm/lightning/soundstorm.py:351, in SoundStorm.iterative_decoding(self, semantic_tokens, max_seq_len, iterations, score_strategies, temperature, sampled_t, seed_tokens)
#     348 probs = logits[:, q].softmax(dim=-1)
#     349 masked_positions = audio_tokens[:, q] == self.mask_token_id
# --> 351 if masked_positions.sum() == 0:
#     352     continue
#     354 if step_idx == q_iter - 1:
#     355     # greedy decoding for the last iteration
#
# KeyboardInterrupt:
